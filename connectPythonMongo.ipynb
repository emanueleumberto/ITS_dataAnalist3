# %% [markdown]
# Creare un Database con MongoDB https://www.mongodb.com/ | https://cloud.mongodb.com/
# DB Mongo https://www.mongodb.com/it-it/resources/languages/python
# https://www.mongodb.com/docs/manual/tutorial/query-documents/
# https://www.mongodb.com/docs/manual/reference/sql-comparison/
# https://www.mongodb.com/docs/manual/data-modeling/concepts/embedding-vs-references/#std-label-data-modeling-referencing
#
# Scaricare ed installare Compass per la gestione del DB Mongo in locale
#
# Tramite PIP installare PyMongo su python
# python -m pip install "pymongo[srv]"

# %%
from pymongo import MongoClient

# Mi collego al cluster di MongoDB tramite la stringa di connessione
cluster = MongoClient('mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
# print(cluster)

# Leggo una lista di database presenti nel cluster
dbList = cluster.list_database_names()
# print(dbList)

# Controllo se nel cluster è presente un database di nome DataMongoPython2
if "DataMongoPython2" in dbList:
    print("DataMongoPython2 database exists!")
    
    # assegno alla variabile db il database di nome DataMongoPython2 presente nel cluster
    db = cluster.DataMongoPython2
    # assegno alla variabile users la collection users presente nel database DataMongoPython2
    users = db['Users']
    # print(users)
    
    # Elimino una collection di nome Users e se non ci sono altre collection elimina anche il DB
    users.drop()
else:
    print("DataMongoPython2 database NOT exists!")
# Out:
# DataMongoPython2 database exists!

# %%
from pymongo import MongoClient

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']
users = db['Users']

# Inserire dati nella collection -> INSERT INTO nomeTabella in SQL
# Per inserire un record in MongoDB, utilizziamo il metodo insert_one()
# Il metodo insert_one() restituisce un oggetto di tipo InsertOneResult,
# che ha una proprietà di nome inserted_id che contiene il valore ID 
# dell'oggetto inserito nella collection

dict = {
    "firstname": "Mario", 
    "lastname": "Rossi", 
    "city": "Roma", 
    "age": 45
    }
# result = users.insert_one(dict)
# if result.inserted_id:
#    print(result.inserted_id, "created!!!")

# Per inserire più dizionari in una collection MongoDB
# utilizziamo il metodo insert_many()
# Il metodo insert_many() restituisce un oggetto di tipo InsertManyResult
# che ha una proprietà di nome inserted_ids che contiene i valori ID
# degli oggetti inseriti nella collection

lista = [
    {"firstname": "Giuseppe", "lastname": "Verdi", "city": "Milano", "age": 21},
    {"firstname": "Francesca", "lastname": "Neri", "city": "Torino", "age": 39},
    {"firstname": "Antonio", "lastname": "Bianchi", "city": "Napoli", "age": 40}
]

# result = users.insert_many(lista)
#if result.inserted_ids:
#    print(result.inserted_ids, "created!!!")

# %%
from pymongo import MongoClient

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']
users = db['Users']

# Leggere dati nella collection -> SELECT di SQL
# Per leggere dati da una collection in MongoDB possiamo utilizzare il metodo 
# find_one() -> restituisce la prima occorrenza della selezione

obj = users.find_one()
# print(obj)
# print(obj['firstname'], obj['lastname'])

# Per leggere tutti i dati da una collection in mongo DB possiamo utilizzare
# il metodo find() -> restituisce tutte le occorrenze della selezione

lista = users.find()
# print(lista)
# for u in lista:
    # print(u)
    # print(u['firstname'], u['lastname'])
    
# Filtrare dati nella collection
# utilizzando il metodo find o find_one il primo paramentro che passo al metodo
# è un oggetto di tipo query e possiamo utilizzarlo per filtrare i risultati

lista = users.find({"city": "Roma"})
# print(lista)
# for u in lista:
    # print(u)
    # print(u['firstname'], u['lastname'])


# Seleziono tutti gli oggetti in cui la proprietà city è contenuta($in) in un set di valori

lista = users.find({"city": {"$in": ["Roma", "Milano", "Palermo"]}})
# for u in lista:
    # print(u)

# Seleziono tutti gli oggetti in cui la proprietà age è minore($lt)
# di un determinato valore numerico
lista = users.find({"age": {"$lt": 30}})
# for u in lista:
    #print(u)

# Seleziono tutti gli oggetti in cui la proprietà age è maggiore($gt)
# di un determinato valore numerico
lista = users.find({"age": {"$gt": 30}})
# for u in lista:
    #print(u)

# Seleziono tutti gli oggetti in cui la proprietà city  
# AND la proprietà firstname hanno un determianto valore
lista = users.find({"city": "Roma", "firstname": "Mario"})
#for u in lista:
    #print(u)
    
# Seleziono tutti gli oggetti in cui la proprietà city  
# OR la proprietà firstname hanno un determianto valore
lista = users.find({"$or": [{"city": "Roma"}, {"firstname": "Giuseppe"}]})
#for u in lista:
    #print(u)
    
# Seleziono tutti gli oggetti filtrati tramite espressioni regolari 
# In questo caso abbiamo selezionato tutti gli utenti che hanno 
# una città che comincia per M
lista = users.find({"city": {"$regex": "^M"}})
# for u in lista:
    #print(u)
    
# Utilizzando il metodo sort() ho la possibilità di ordinare i dati
# in ordine crescente o decrescente
# sort(field, 1) -> Crescente
# sort(field, -1) -> Decrescente
lista = users.find().sort('age', -1)
#for u in lista:
    #print(u)

# Per limitare o paginare i risultati di una ricerca in MongoDB 
# possiamo utilizzare il metodo limit(limit:int) come paramentro,
# inserire ilnumero di risultati che si vuole visualizzare
# Con il metodo skip(skip:int) posso indicare il numero di 
# risultati da escludere dalla richiesta
lista = users.find().limit(3).skip(0)
for u in lista:
    print(u)

# %%
from pymongo import MongoClient

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']
users = db['Users']

# Modificare un dato nella collection MongoDB -> Update in SQL
# update_one(filter, update)
# update_many(filter, update)

# il primo parametro del metodo update_one() è un oggetto di tipo query
# che definisce quale elemento aggiornate, il secondo parametro è
# è un oggetto con le modifiche da applicare all'elemento selezionato

result = users.update_one({"city": "Milano"},{"$set": {"firstname": "Simone", "age": 99}})
print(result.modified_count, "modified!!!")


# il primo parametro del metodo update_many() è un oggetto di tipo query
# che definisce quale elemento aggiornate, il secondo parametro è
# è un oggetto con le modifiche da applicare a tutti gli elementi selezionato

result = users.update_many({"firstname": {"$regex": "^A"}}, {"$set": {"age": 10}})
print(result.modified_count, "modified!!!")
# Out:
# 0 modified!!!
# 0 modified!!!

# %%
from pymongo import MongoClient

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']
users = db['Users']

# Eliminare un dato da una collection -> DELETE in SQL
# delete_one(filter)
# delete_many(filter)

# Il parametro del metodo delete_one è un oggetto di tipo query
# che definisce quale elemento eliminare nella collection
result = users.delete_one({"city": "Napoli"})
print(result.deleted_count, "deleted!!!")

# Il parametro del metodo delete_many è un oggetto di tipo query
# che definisce tutti gli elementi da eliminare nella collection
result = users.delete_many({"city": "Milano"})
print(result.deleted_count, "deleted!!!")

# %%
from pymongo import MongoClient

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']

# Controllo se è presente nel mio DB una collection con il nome Peoples
if "Peoples" not in db.list_collection_names():
    # Se non presente la crea, altrimenti la ignora
    db.create_collection("Peoples")

peoples = db['Peoples']

# Embedded VS References

# Embedded
# Annido un oggetto completo in una proprietà del dizionario
dict = {
    "name": "Mario",
    "lastname": "Rossi",
    "age": 23,
    "active": True,
    "address": {
        "street": "Via angelo Emo, 13",
        "city": "Roma"
    },
    "language": ["Italiano", "Inglese", "Francese"]
}

# salvo i dati del dizionario nella collection
# result = peoples.insert_one(dict)
# print(result.inserted_id, "created!")

# Leggo i dati del dizionario presente nella collection e ne stampo i valori
obj = peoples.find_one({"name": "Mario"})
print(obj)
print(obj["name"], obj["lastname"], obj["address"]["city"], obj["language"][1])

# %%
from pymongo import MongoClient
from datetime import datetime

connectionString = 'mongodb+srv://admin:md75U6GzY7aY7YpG@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
cluster = MongoClient(connectionString)
db = cluster['DataMongoPython2']

if "Cart" not in db.list_collection_names():
    # Se non presente la crea, altrimenti la ignora
    db.create_collection("Cart")

peoples = db['Peoples']
cart = db['Cart']

# Embedded VS References

dict = {
    "name": "Giuseppe",
    "lastname": "Verdi",
    "age": 41,
    "active": True,
    "address": {
        "street": "Via marconi, 5",
        "city": "Milano"
    },
    "language": ["Inglese"]
}

# result = peoples.insert_one(dict)
# print(result.inserted_id, "created!")

# References
# Leggo i dati del dizionario presente nella collection
verdi = peoples.find_one({"name": "Giuseppe"})
# Salvo i dati su due o più collection diverse mettendo 
# in relazione i dati tramite reference sul campo id
cartDict = {
    "products": ["Apple Iphone", "Google Chromebook"],
    "date": datetime.now(),
    "people_id": verdi["_id"]
}

# result = cart.insert_one(cartDict)
# print(result.inserted_id, "created!")

verdi = peoples.find_one({"name": "Giuseppe"})
print(verdi)

cartList = cart.find({"people_id": verdi["_id"]})
for cart in cartList:
    print(cart)
# Out:
# {'_id': ObjectId('6874bd18139e2c936f2a07f3'), 'name': 'Giuseppe', 'lastname': 'Verdi', 'age': 41, 'active': True, 'address': {'street': 'Via marconi, 5', 'city': 'Milano'}, 'language': ['Inglese']}
# {'_id': ObjectId('6874c07f139e2c936f2a07f5'), 'products': ['Apple Iphone', 'Google Chromebook'], 'date': datetime.datetime(2025, 7, 14, 10, 31, 59, 748000), 'people_id': ObjectId('6874bd18139e2c936f2a07f3')}
